# %% [markdown]
# 1)  Create a directory
#     put a file inside the directory
#     write data inside the file
#     Delete the directory

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Assignment'

# %%
os.mkdir("Assignment")

# %%
os.listdir(os.getcwd())
# Out:
# []

# %%
os.chdir("C:/Users/Administrator/Assignment")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Assignment'

# %%
fp=open("sample.txt","w")
st="This is first sentence \n this is second sentence \n this is third sentence"
fp.write(st)
fp.close()

# %%
fp=open("sample.txt","r")
print(fp.read())
fp.close()
# Out:
# This is first sentence
#  this is second sentence
#  this is third sentence

# %%
import shutil
os.chdir("C:/Users/Administrator/")
shutil.rmtree("C:/Users/Administrator/Assignment")
